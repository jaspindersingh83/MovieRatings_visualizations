# %%
import matplotlib.pyplot as plt
import pandas as pd
reviews=pd.read_csv("fandango_score_comparison.csv")
norm_reviews=reviews[['FILM','RT_user_norm','Metacritic_user_nom','IMDB_norm','Fandango_Ratingvalue','Fandango_Stars']]
norm_reviews.head()
# Out:
#                              FILM  RT_user_norm  Metacritic_user_nom  \
# 0  Avengers: Age of Ultron (2015)           4.3                 3.55
# 1               Cinderella (2015)           4.0                 3.75
# 2                  Ant-Man (2015)           4.5                 4.05
# 3          Do You Believe? (2015)           4.2                 2.35
# 4   Hot Tub Time Machine 2 (2015)           1.4                 1.70
#
#    IMDB_norm  Fandango_Ratingvalue  Fandango_Stars
# 0       3.90                   4.5             5.0
# 1       3.55                   4.5             5.0
# 2       3.90                   4.5             5.0
# 3       2.70                   4.5             5.0
# 4       2.55                   3.0             3.5

# %%
#### Draw bar plot to compare ratings of other sites with Fandango

name_columns=norm_reviews.columns.tolist()
from numpy import arange
bar_positions=arange(5)+0.75
bar_positions=bar_positions.tolist()
bar_heights=norm_reviews.iloc[0,:].tolist()[1:]
fig=plt.figure(figsize=(8,5))
ax=fig.add_subplot(1,1,1)
tick_positions=range(1,6)
ax.bar(left=bar_positions,height=bar_heights,width=0.5,align='center')
ax.xaxis.set(ticks=tick_positions, ticklabels=name_columns)
plt.xticks(rotation=90)
ax.set(title="Average User Rating For Avengers: Age of Ultron (2015)", ylabel="Average Rating", xlabel="Rating Source")
plt.show()

# %%
### Creating a horizontal bar plot 
fig=plt.figure(figsize=(8,5))
ax=fig.add_subplot(1,1,1)
tick_positions=range(1,6)
ax.barh(bottom=bar_positions,width=bar_heights,height=0.5,align='center')
ax.yaxis.set(ticks=tick_positions, ticklabels=name_columns)
ax.set(title="Average User Rating For Avengers: Age of Ultron (2015)", xlabel="Average Rating", ylabel="Rating Source")
plt.show()

# %%
### Scatter Plot to determine corelations
fig1=plt.figure(figsize=(8,5))
ax1=fig1.add_subplot(1,1,1)
ax1.scatter(norm_reviews['Fandango_Ratingvalue'],norm_reviews['RT_user_norm'])
ax1.set(xlabel="Fandango", ylabel="Rotten Tomatoes")
plt.show()

# %%
## Creating the Scatter Plot by exchanging axes
fig1=plt.figure()
ax1=fig1.add_subplot(2,1,1)
ax2=fig1.add_subplot(2,1,2)
ax1.scatter(norm_reviews['Fandango_Ratingvalue'],norm_reviews['RT_user_norm'])
ax1.set(xlabel="Fandango", ylabel="Rotten Tomatoes")
ax2.scatter(norm_reviews['RT_user_norm'],norm_reviews['Fandango_Ratingvalue'])
ax2.set(ylabel="Fandango", xlabel="Rotten Tomatoes")
plt.show()

# %%
### Benchmarking with other ratings and Fandango

fig = plt.figure(figsize=(5,10))
ax1 = fig.add_subplot(3,1,1)
ax2 = fig.add_subplot(3,1,2)
ax3 = fig.add_subplot(3,1,3)

ax1.scatter(norm_reviews['Fandango_Ratingvalue'],norm_reviews['RT_user_norm'])
ax1.set(xlabel="Fandango", ylabel="Rotten Tomatoes")

ax2.scatter(norm_reviews['Fandango_Ratingvalue'],norm_reviews['Metacritic_user_nom'])
ax2.set(xlabel="Fandango", ylabel="Metacritic")


ax3.scatter(norm_reviews['Fandango_Ratingvalue'],norm_reviews['IMDB_norm'])
ax3.set(xlabel="Fandango", ylabel="IMDB")

plt.show()

# %%
fandango_distribution=norm_reviews['Fandango_Ratingvalue'].value_counts().sort_index()
imdb_distribution=norm_reviews['IMDB_norm'].value_counts().sort_index()
fig,ax=plt.subplots()
ax.hist(norm_reviews['Fandango_Ratingvalue'],range=(0,5),color='r')
plt.show()

# %%
fig = plt.figure(figsize=(5,20))
ax1 = fig.add_subplot(4,1,1)
ax2 = fig.add_subplot(4,1,2)
ax3 = fig.add_subplot(4,1,3)
ax4 = fig.add_subplot(4,1,4)
ax1.hist(norm_reviews['Fandango_Ratingvalue'],range=(0,5),bins=20)
ax2.hist(norm_reviews['RT_user_norm'],range=(0,5),bins=20)
ax3.hist(norm_reviews['Metacritic_user_nom'],range=(0,5),bins=20)
ax4.hist(norm_reviews['IMDB_norm'],range=(0,5),bins=20)
plt.show()

# %%
##Creating a box plot for looking at quartiles

fig,ax=plt.subplots()
ax.boxplot(norm_reviews['RT_user_norm'])
ax.set(ylim=(0,5))
ax.xaxis.set(ticklabels=['Roten Tomatoes'])
plt.show()

# %%
name_columns
fig,ax=plt.subplots()

ax.boxplot(norm_reviews[name_columns].values)
plt.show()
